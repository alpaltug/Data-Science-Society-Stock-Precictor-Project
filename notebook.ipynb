# %%
! pip install -U textblob
! python -m textblob.download_corpora


import pandas as pd
import json
from textblob import TextBlob
import nltk
nltk.download('punkt')

from textblob import TextBlob, Word, Blobber
from textblob.classifiers import NaiveBayesClassifier
from textblob.taggers import NLTKTagger
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.
# ...

# %%
#Scraping to increase the number of tweets

# !snscrape --max-results 1000 --jsonl twitter-hashtag nytimes > /work/data/nytimes2.txt
# Out:
# ^C
# Traceback (most recent call last):
#   File "/root/venv/bin/snscrape", line 8, in <module>
#     sys.exit(main())
#   File "/root/venv/lib/python3.9/site-packages/snscrape/_cli.py", line 308, in main
#     for i, item in enumerate(scraper.get_items(), start = 1):
#   File "/root/venv/lib/python3.9/site-packages/snscrape/modules/twitter.py", line 680, in get_items
#     for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', params, paginationParams, cursor = self._cursor):
#   File "/root/venv/lib/python3.9/site-packages/snscrape/modules/twitter.py", line 369, in _iter_api_data
#     obj = self._get_api_data(endpoint, reqParams)
#   File "/root/venv/lib/python3.9/site-packages/snscrape/modules/twitter.py", line 339, in _get_api_data
#     r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = self._check_api_response)
#   File "/root/venv/lib/python3.9/site-packages/snscrape/base.py", line 216, in _get
# ...

# %%
#Scraping

# !snscrape --max-results 1000 --jsonl twitter-hashtag appl > /work/data/appl_data2.txt

# !snscrape --max-results 1000 --jsonl twitter-hashtag tesla > /work/data/tesla2.txt

# !snscrape --max-results 1000 --jsonl twitter-hashtag amazon > /work/data/amazon2.txt

# !snscrape --max-results 1000 --jsonl twitter-hashtag bitcoin > /work/data/bitcoin2.txt

# !snscrape --max-results 1000 --jsonl twitter-hashtag google > /work/data/google2.txt

# !snscrape --max-results 1000 --jsonl twitter-hashtag meta > /work/data/meta2.txt

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.ticker as ticker
from matplotlib import pyplot as plt
import datetime

# %%
list_nytimes = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/nytimes.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_nytimes.append(tweet)

df_nytimes = pd.DataFrame(list_nytimes)
df_nytimes
nytimes_content = df_nytimes['content'].tolist()
list = []

for sentence in nytimes_content:
    blob += TextBlob(sentence)
arr = []
for sentence in blob.sentences:
    arr.append(sentence.sentiment.polarity)

print(np.average(arr))
# Out:
# Started Reading JSON file which contains multiple JSON document
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-4d81a9c68af8> in <cell line: 15>()
#      14
#      15 for sentence in nytimes_content:
# ---> 16     blob += TextBlob(sentence)
#      17 arr = []
#      18 for sentence in blob.sentences:
#
# NameError: name 'blob' is not defined

# %%
list_bitcoin = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/bitcoin.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_bitcoin.append(tweet)

df_btc = pd.DataFrame(list_bitcoin)
df_btc[['date', 'content', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount']]


df_content = df_btc['content']

for sentence in df_content:
    blob += TextBlob(sentence)
arr = []
for sentence in blob.sentences:
    arr.append(sentence.sentiment.polarity)

print(np.average(arr))
# Out:
# Started Reading JSON file which contains multiple JSON document
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-99661aa779a5> in <cell line: 14>()
#      13
#      14 for sentence in df_content:
# ---> 15     blob += TextBlob(sentence)
#      16 arr = []
#      17 for sentence in blob.sentences:
#
# NameError: name 'blob' is not defined

# %%
list_amazon = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/amazon.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_amazon.append(tweet)

df_amazon = pd.DataFrame(list_amazon)
df_amazon[['date', 'content', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount']]

df_amazon['content'][1]
# Out:
# Started Reading JSON file which contains multiple JSON document
# 'The amount of plastic &amp; energy used... staggering.  RT: Amazon has launched its own line of sustainable products, called Amazon Aware. https://t.co/gTaWn6QUQ6 #news #amazon #sustainable fashion'

# %%
_deepnote_run_altair(df_amazon, """{"$schema":"https://vega.github.io/schema/vega-lite/v4.json","mark":{"type":"line","tooltip":{"content":"data"}},"height":220,"autosize":{"type":"fit"},"data":{"name":"placeholder"},"encoding":{"x":{"field":"date","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}},"y":{"field":"COUNT(*)","type":"quantitative","sort":null,"aggregate":"count","scale":{"type":"linear","zero":false}},"color":{"field":"","type":"nominal","sort":null,"scale":{"type":"linear","zero":false}}}}""")
# Out:
# alt.Chart(...)

# %%
list_appl = []
with open('/work/data/appl.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_appl.append(tweet)

df_appl = pd.DataFrame(list_appl)
df_appl['content'][1]
# Out:
# '今日の投資状況。EPIは少し下げ。KMBは強い下げ。APPLは強い下げ。KRUSは強い上げ。MCDは少し下げ。MSFTは少し下げ。３倍ETFはどれも少し強めに下げでした。バーゲンセールはいつまで続くのか？#米国株 #株式投資 #TECL #SOXL #WEBL #MCD #EPI #KMB #MSFT #APPL #KRUS https://t.co/uixplr2I8D'

# %%
list_meta = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/meta.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_meta.append(tweet)

df_meta = pd.DataFrame(list_meta)
df_meta
# Out:
# Started Reading JSON file which contains multiple JSON document
#                               _type  \
# 0    snscrape.modules.twitter.Tweet
# 1    snscrape.modules.twitter.Tweet
# 2    snscrape.modules.twitter.Tweet
# 3    snscrape.modules.twitter.Tweet
# 4    snscrape.modules.twitter.Tweet
# ..                              ...
# 995  snscrape.modules.twitter.Tweet
# 996  snscrape.modules.twitter.Tweet
# 997  snscrape.modules.twitter.Tweet
# 998  snscrape.modules.twitter.Tweet
# 999  snscrape.modules.twitter.Tweet
#
#                                                    url  \
# 0    https://twitter.com/Koekaktus/status/150394290...
# 1    https://twitter.com/sayurmayur795/status/15039...
# 2    https://twitter.com/MdNurHabib6/status/1503942...
# 3    https://twitter.com/Toru19710111/status/150394...
# 4    https://twitter.com/koinhopper/status/15039415...
# ..                                                 ...
# 995  https://twitter.com/cryptscp/status/1503722962...
# ...

# %%
list_google = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/google.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_google.append(tweet)

df_google = pd.DataFrame(list_google)

fig, ax = plt.subplots(figsize = (25,10),  x="date",y='content') # This increases plot size
sns.set(font_scale = 1.2)

plt.bar(data=df_google)

plt.xticks(rotation = 45)
# Out:
# Started Reading JSON file which contains multiple JSON document
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-29b432228d36> in <cell line: 10>()
#       8 df_google = pd.DataFrame(list_google)
#       9
# ---> 10 fig, ax = plt.subplots(figsize = (25,10),  x="date",y='content') # This increases plot size
#      11 sns.set(font_scale = 1.2)
#      12
#
# /shared-libs/python3.9/py/lib/python3.9/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1432
#    1433     """
# -> 1434     fig = figure(**fig_kw)
#    1435     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1436                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# ...

# %%
list_nvda = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/nytimes.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_nvda.append(tweet)

df_nvda = pd.DataFrame(list_nvda)
# Out:
# Started Reading JSON file which contains multiple JSON document

# %%
list_ethereum = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/eth.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_ethereum.append(tweet)

df_ethereum = pd.DataFrame(list_ethereum)

# %%
list_msft = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/msft.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_ethereum.append(tweet)

df_msft = pd.DataFrame(list_msft)

# %%
list_explore = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/nytimes.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_explore.append(tweet)

df_explore = pd.DataFrame(list_explore)
# Out:
# Started Reading JSON file which contains multiple JSON document

# %%
list_wallstreet = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/nytimes.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_wallstreet.append(tweet)

df_wallstreet = pd.DataFrame(list_wallstreet)

# %%
# !snscrape --max-results 1000 --jsonl twitter-hashtag putin > /work/data/putin.txt

list_putin = []
print("Started Reading JSON file which contains multiple JSON document")
with open('/work/data/putin.txt') as f:
    for jsonObj in f:
        tweet = json.loads(jsonObj)
        list_putin.append(tweet)

df_putin = pd.DataFrame(list_putin)
df_putin
putin_content = df_putin['content'].tolist()

str1 = ''
for i in putin_content:
    str += (" " + i)

blob = TextBlob(putin_content)
arr1 = []
for sentence in blob.sentences:
    arr1.append(sentence.sentiment.polarity)

print(blob)
# Out:
# Started Reading JSON file which contains multiple JSON document
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-0e8c7eac5781> in <cell line: 15>()
#      14 str1 = ''
#      15 for i in putin_content:
# ---> 16     str += (" " + i)
#      17
#      18 blob = TextBlob(putin_content)
#
# TypeError: unsupported operand type(s) for +=: 'type' and 'str'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=bc974696-5c14-40f5-86a4-29ffa8a96f2c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
